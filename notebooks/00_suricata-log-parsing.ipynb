# %%
import os
import json 
import pandas as pd

# %% [markdown]
# ### FILE PREPARATION

# %%
CWD = os.getcwd()
DATA_FOLDER = os.path.join(CWD, 'data')
SUR_SSH_FOLDER = os.path.join(DATA_FOLDER, "suricata", "ssh")
SUR_FTP_FOLDER = os.path.join(DATA_FOLDER, "suricata", "ftp")
SUR_DVWA_FOLDER = os.path.join(DATA_FOLDER, "suricata", "dvwa")

# %%
EVE_SSH_PATH = os.path.join(SUR_SSH_FOLDER, 'eve.json')
EVE_FTP_PATH = os.path.join(SUR_FTP_FOLDER, 'eve.json')
EVE_DVWA_PATH = os.path.join(SUR_DVWA_FOLDER, 'eve.json')

# %% [markdown]
# ### DATA PREPATATION

# %%
def read_file(file_path):
    with open(file_path) as f:
        raw_file = f.readlines()
    return raw_file

# %%
def line_to_json(line):
    return json.loads(line)

# %%
def read_eve_file(file_path):
    raw_eve = read_file(file_path)
    json_eve = []
    for l in raw_eve:
        json_eve.append(line_to_json(l))
    return json_eve

# %% [markdown]
# #### JSON

# %%
eve_ssh_json = read_eve_file(EVE_SSH_PATH)
eve_ftp_json = read_eve_file(EVE_FTP_PATH)
eve_dvwa_json = read_eve_file(EVE_DVWA_PATH)

eve_jsons = {
    'ssh': eve_ssh_json,
    'ftp': eve_ftp_json,
    'dvwa': eve_dvwa_json 
}

# %% [markdown]
# #### DATAFRAME

# %%
eve_ssh_df = pd.DataFrame(eve_ssh_json)
eve_ftp_df = pd.DataFrame(eve_ftp_json)
eve_dvwa_df = pd.DataFrame(eve_dvwa_json)

eve_dfs = {
    'ssh': eve_ssh_df,
    'ftp': eve_ftp_df,
    'dvwa': eve_dvwa_df 
}

# %% [markdown]
# ### FUNCTIONS

# %%
def filter_json_data(data: list[dict], key, value, comparator):
    if comparator == '==':
        return list(filter(lambda d: d[key] == value, data))
    elif comparator == '!=':
        return list(filter(lambda d: d[key] != value, data))
    else:
        raise NotImplementedError(f'Not implemented filtering for comporator "{comparator}"!')

# %%
def join_jsons(json_data: list[json]):
    result = []
    for data in json_data:
        result.extend(data)
    return result

# %%
def save_json(json_to_save, file_name):
    with open(f'results/{file_name}', 'w') as f:
        json.dump(json_to_save, f, indent=4)

# %% [markdown]
# #### COLUMNS

# %%
all_columns = []
for df in eve_dfs.values():
    all_columns.extend(df.columns.to_list())
all_columns = set(all_columns)

columns_in_dfs = []
for column in all_columns:
    result = {'column': column}
    for name, df in eve_dfs.items():
        columns = df.columns.to_list()
        result[name] = int(column in columns)
    columns_in_dfs.append(result)
columns_in_dfs = pd.DataFrame(columns_in_dfs)

# %%
columns_in_dfs.to_csv('results/columns_in_eve_dfs.csv', index=False)

# %% [markdown]
# ##### EVENT TYPES

# %%
for name, df in eve_dfs.items():
    print(name.upper())
    print(f'event types: {df['event_type'].unique()}')
    print()
# Out:
# SSH
# event types: ['ssh' 'stats' 'flow']
#
# FTP
# event types: ['stats' 'flow' 'ftp' 'alert' 'anomaly']
#
# DVWA
# event types: ['stats' 'http' 'flow' 'fileinfo']

# %% [markdown]
# Description:
#
#     'flow' – contains connection metadata: IPs, ports, packet/byte counts, duration, TCP flags
#     → Important
#
#     'stats' – internal Suricata statistics (packet counts, memory usage, errors)
#     → Not important
#
#     'alert' – triggered IDS rules with signature, category, and severity
#     → Important
#
#     'anomaly' – protocol parsing issues or unexpected behavior
#     → Moderately important
#
#     'ssh' – SSH handshake data: protocol versions, client/server info, algorithms
#     → Important
#
#     'ftp' – FTP commands, replies, and session details
#     → Important
#
#     'http' – HTTP method, URL, headers, user-agent, content-type
#     → Important
#
#     'fileinfo' – file transfers: filename, MIME type, size, hash
#     → Important

# %% [markdown]
# ### FLOW event type

# %%
flow_jsons = {name: filter_json_data(json_data, 'event_type', 'flow', '==') for name, json_data in eve_jsons.items()}

# %%
flow_jsons
# Out:
# {'ssh': [{'timestamp': '2025-07-10T16:50:32.430730+0000',
#    'flow_id': 1523555128178732,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': '172.24.0.6',
#    'src_port': 34674,
#    'dest_ip': '172.24.0.4',
#    'dest_port': 22,
#    'proto': 'TCP',
#    'app_proto': 'ssh',
#    'flow': {'pkts_toserver': 21,
#     'pkts_toclient': 21,
#     'bytes_toserver': 4786,
#     'bytes_toclient': 5164,
#     'start': '2025-07-10T16:49:25.682410+0000',
#     'end': '2025-07-10T16:49:25.942650+0000',
#     'age': 0,
#     'state': 'closed',
#     'reason': 'timeout',
#     'alerted': False},
#    'tcp': {'tcp_flags': '1b',
#     'tcp_flags_ts': '1b',
#     'tcp_flags_tc': '1b',
#     'syn': True,
#     'fin': True,
#     'psh': True,
#     'ack': True,
#     'state': 'closed',
#     'ts_max_regions': 1,
#     'tc_max_regions': 1}},
#   {'timestamp': '2025-07-10T16:50:33.425045+0000',
#    'flow_id': 480210616721987,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': 'fe80:0000:0000:0000:9c2b:a8ff:fe1a:b548',
#    'dest_ip': 'ff02:0000:0000:0000:0000:0000:0000:0002',
#    'proto': 'IPv6-ICMP',
#    'icmp_type': 133,
#    'icmp_code': 0,
#    'flow': {'pkts_toserver': 2,
#     'pkts_toclient': 0,
#     'bytes_toserver': 140,
#     'bytes_toclient': 0,
#     'start': '2025-07-10T16:49:29.636095+0000',
#     'end': '2025-07-10T16:49:59.789513+0000',
#     'age': 30,
#     'state': 'new',
#     'reason': 'timeout',
#     'alerted': False}},
#   {'timestamp': '2025-07-10T16:51:04.236446+0000',
#    'flow_id': 902801768084437,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': '172.24.0.6',
#    'src_port': 52234,
#    'dest_ip': '172.24.0.4',
#    'dest_port': 22,
#    'proto': 'TCP',
#    'app_proto': 'ssh',
#    'flow': {'pkts_toserver': 23,
#     'pkts_toclient': 21,
#     'bytes_toserver': 4902,
#     'bytes_toclient': 5388,
#     'start': '2025-07-10T16:50:03.079127+0000',
#     'end': '2025-07-10T16:50:03.340454+0000',
#     'age': 0,
#     'state': 'closed',
#     'reason': 'timeout',
#     'alerted': False},
#    'tcp': {'tcp_flags': '1b',
#     'tcp_flags_ts': '1b',
#     'tcp_flags_tc': '1b',
#     'syn': True,
#     'fin': True,
#     'psh': True,
#     'ack': True,
#     'state': 'closed',
#     'ts_max_regions': 1,
#     'tc_max_regions': 1}},
#   {'timestamp': '2025-07-10T16:51:12.207076+0000',
#    'flow_id': 1188339054682691,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': 'fe80:0000:0000:0000:9c2b:a8ff:fe1a:b548',
#    'dest_ip': 'ff02:0000:0000:0000:0000:0000:0000:0002',
#    'proto': 'IPv6-ICMP',
#    'icmp_type': 133,
#    'icmp_code': 0,
#    'flow': {'pkts_toserver': 1,
#     'pkts_toclient': 0,
#     'bytes_toserver': 70,
#     'bytes_toclient': 0,
#     'start': '2025-07-10T16:51:00.145609+0000',
#     'end': '2025-07-10T16:51:00.145609+0000',
#     'age': 0,
#     'state': 'new',
#     'reason': 'shutdown',
#     'alerted': False}},
#   {'timestamp': '2025-07-10T16:51:12.207143+0000',
#    'flow_id': 1775119914859501,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': '172.24.0.6',
#    'src_port': 54772,
#    'dest_ip': '172.24.0.4',
#    'dest_port': 22,
#    'proto': 'TCP',
#    'app_proto': 'ssh',
#    'flow': {'pkts_toserver': 22,
#     'pkts_toclient': 20,
#     'bytes_toserver': 4884,
#     'bytes_toclient': 5038,
#     'start': '2025-07-10T16:51:10.216694+0000',
#     'end': '2025-07-10T16:51:10.479610+0000',
#     'age': 0,
#     'state': 'closed',
#     'reason': 'shutdown',
#     'alerted': False},
#    'tcp': {'tcp_flags': '1b',
#     'tcp_flags_ts': '1b',
#     'tcp_flags_tc': '1b',
#     'syn': True,
#     'fin': True,
#     'psh': True,
#     'ack': True,
#     'state': 'closed',
#     'ts_max_regions': 1,
#     'tc_max_regions': 1}}],
#  'ftp': [{'timestamp': '2025-07-10T16:50:05.526820+0000',
#    'flow_id': 1456779904563782,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': 'fe80:0000:0000:0000:e86a:61ff:fe82:64d5',
#    'dest_ip': 'ff02:0000:0000:0000:0000:0000:0000:0002',
#    'proto': 'IPv6-ICMP',
#    'icmp_type': 133,
#    'icmp_code': 0,
#    'flow': {'pkts_toserver': 1,
#     'pkts_toclient': 0,
#     'bytes_toserver': 70,
#     'bytes_toclient': 0,
#     'start': '2025-07-10T16:49:33.732399+0000',
#     'end': '2025-07-10T16:49:33.732399+0000',
#     'age': 0,
#     'state': 'new',
#     'reason': 'timeout',
#     'alerted': False}},
#   {'timestamp': '2025-07-10T16:50:41.302799+0000',
#    'flow_id': 1482231880759878,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': 'fe80:0000:0000:0000:e86a:61ff:fe82:64d5',
#    'dest_ip': 'ff02:0000:0000:0000:0000:0000:0000:0002',
#    'proto': 'IPv6-ICMP',
#    'icmp_type': 133,
#    'icmp_code': 0,
#    'flow': {'pkts_toserver': 1,
#     'pkts_toclient': 0,
#     'bytes_toserver': 70,
#     'bytes_toclient': 0,
#     'start': '2025-07-10T16:50:05.934933+0000',
#     'end': '2025-07-10T16:50:05.934933+0000',
#     'age': 0,
#     'state': 'new',
#     'reason': 'timeout',
#     'alerted': False}},
#   {'timestamp': '2025-07-10T16:51:12.118917+0000',
#    'flow_id': 477980419548945,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': '172.24.0.6',
#    'src_port': 42756,
#    'dest_ip': '172.24.0.5',
#    'dest_port': 21,
#    'proto': 'TCP',
#    'app_proto': 'ftp',
#    'app_proto_ts': 'failed',
#    'flow': {'pkts_toserver': 8,
#     'pkts_toclient': 11,
#     'bytes_toserver': 577,
#     'bytes_toclient': 863,
#     'start': '2025-07-10T16:50:33.111288+0000',
#     'end': '2025-07-10T16:50:33.159291+0000',
#     'age': 0,
#     'state': 'closed',
#     'reason': 'shutdown',
#     'alerted': True},
#    'metadata': {'flowints': {'applayer.anomaly.count': 1}},
#    'tcp': {'tcp_flags': '1b',
#     'tcp_flags_ts': '1b',
#     'tcp_flags_tc': '1b',
#     'syn': True,
#     'fin': True,
#     'psh': True,
#     'ack': True,
#     'state': 'closed',
#     'ts_max_regions': 1,
#     'tc_max_regions': 1}},
#   {'timestamp': '2025-07-10T16:51:12.139990+0000',
#    'flow_id': 1165813050128966,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': 'fe80:0000:0000:0000:e86a:61ff:fe82:64d5',
#    'dest_ip': 'ff02:0000:0000:0000:0000:0000:0000:0002',
#    'proto': 'IPv6-ICMP',
#    'icmp_type': 133,
#    'icmp_code': 0,
#    'flow': {'pkts_toserver': 1,
#     'pkts_toclient': 0,
#     'bytes_toserver': 70,
#     'bytes_toclient': 0,
#     'start': '2025-07-10T16:51:08.336973+0000',
#     'end': '2025-07-10T16:51:08.336973+0000',
#     'age': 0,
#     'state': 'new',
#     'reason': 'shutdown',
#     'alerted': False}}],
#  'dvwa': [{'timestamp': '2025-07-10T16:50:07.981889+0000',
#    'flow_id': 1456603265356947,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': 'fe80:0000:0000:0000:8470:84ff:fe63:c643',
#    'dest_ip': 'ff02:0000:0000:0000:0000:0000:0000:0002',
#    'proto': 'IPv6-ICMP',
#    'icmp_type': 133,
#    'icmp_code': 0,
#    'flow': {'pkts_toserver': 1,
#     'pkts_toclient': 0,
#     'bytes_toserver': 70,
#     'bytes_toclient': 0,
#     'start': '2025-07-10T16:49:33.732357+0000',
#     'end': '2025-07-10T16:49:33.732357+0000',
#     'age': 0,
#     'state': 'new',
#     'reason': 'timeout',
#     'alerted': False}},
#   {'timestamp': '2025-07-10T16:50:38.394921+0000',
#    'flow_id': 2245820685866131,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': 'fe80:0000:0000:0000:8470:84ff:fe63:c643',
#    'dest_ip': 'ff02:0000:0000:0000:0000:0000:0000:0002',
#    'proto': 'IPv6-ICMP',
#    'icmp_type': 133,
#    'icmp_code': 0,
#    'flow': {'pkts_toserver': 1,
#     'pkts_toclient': 0,
#     'bytes_toserver': 70,
#     'bytes_toclient': 0,
#     'start': '2025-07-10T16:50:07.981647+0000',
#     'end': '2025-07-10T16:50:07.981647+0000',
#     'age': 0,
#     'state': 'new',
#     'reason': 'timeout',
#     'alerted': False}},
#   {'timestamp': '2025-07-10T16:50:56.277284+0000',
#    'flow_id': 843221208094015,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': '172.24.0.6',
#    'src_port': 59110,
#    'dest_ip': '172.24.0.3',
#    'dest_port': 80,
#    'proto': 'TCP',
#    'app_proto': 'http',
#    'flow': {'pkts_toserver': 6,
#     'pkts_toclient': 4,
#     'bytes_toserver': 472,
#     'bytes_toclient': 695,
#     'start': '2025-07-10T16:49:54.786151+0000',
#     'end': '2025-07-10T16:49:54.789143+0000',
#     'age': 0,
#     'state': 'closed',
#     'reason': 'timeout',
#     'alerted': False},
#    'tcp': {'tcp_flags': '1b',
#     'tcp_flags_ts': '1b',
#     'tcp_flags_tc': '1b',
#     'syn': True,
#     'fin': True,
#     'psh': True,
#     'ack': True,
#     'state': 'closed',
#     'ts_max_regions': 1,
#     'tc_max_regions': 1}},
#   {'timestamp': '2025-07-10T16:51:12.181579+0000',
#    'flow_id': 621310068435463,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': '172.24.0.6',
#    'src_port': 56800,
#    'dest_ip': '172.24.0.3',
#    'dest_port': 80,
#    'proto': 'TCP',
#    'app_proto': 'http',
#    'flow': {'pkts_toserver': 6,
#     'pkts_toclient': 4,
#     'bytes_toserver': 484,
#     'bytes_toclient': 695,
#     'start': '2025-07-10T16:50:10.079124+0000',
#     'end': '2025-07-10T16:50:10.084457+0000',
#     'age': 0,
#     'state': 'closed',
#     'reason': 'timeout',
#     'alerted': False},
#    'tcp': {'tcp_flags': '1b',
#     'tcp_flags_ts': '1b',
#     'tcp_flags_tc': '1b',
#     'syn': True,
#     'fin': True,
#     'psh': True,
#     'ack': True,
#     'state': 'closed',
#     'ts_max_regions': 1,
#     'tc_max_regions': 1}},
#   {'timestamp': '2025-07-10T16:51:12.207138+0000',
#    'flow_id': 1953931991844838,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': '172.24.0.6',
#    'src_port': 33174,
#    'dest_ip': '172.24.0.3',
#    'dest_port': 80,
#    'proto': 'TCP',
#    'app_proto': 'http',
#    'flow': {'pkts_toserver': 6,
#     'pkts_toclient': 4,
#     'bytes_toserver': 699,
#     'bytes_toclient': 721,
#     'start': '2025-07-10T16:50:46.389399+0000',
#     'end': '2025-07-10T16:50:46.391540+0000',
#     'age': 0,
#     'state': 'closed',
#     'reason': 'shutdown',
#     'alerted': False},
#    'tcp': {'tcp_flags': '1b',
#     'tcp_flags_ts': '1b',
#     'tcp_flags_tc': '1b',
#     'syn': True,
#     'fin': True,
#     'psh': True,
#     'ack': True,
#     'state': 'closed',
#     'ts_max_regions': 1,
#     'tc_max_regions': 1}},
#   {'timestamp': '2025-07-10T16:51:12.207229+0000',
#    'flow_id': 1395568825346915,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': '172.24.0.6',
#    'src_port': 39772,
#    'dest_ip': '172.24.0.3',
#    'dest_port': 80,
#    'proto': 'TCP',
#    'app_proto': 'http',
#    'flow': {'pkts_toserver': 8,
#     'pkts_toclient': 6,
#     'bytes_toserver': 925,
#     'bytes_toclient': 2530,
#     'start': '2025-07-10T16:51:00.259395+0000',
#     'end': '2025-07-10T16:51:00.279236+0000',
#     'age': 0,
#     'state': 'closed',
#     'reason': 'shutdown',
#     'alerted': False},
#    'tcp': {'tcp_flags': '1b',
#     'tcp_flags_ts': '1b',
#     'tcp_flags_tc': '1b',
#     'syn': True,
#     'fin': True,
#     'psh': True,
#     'ack': True,
#     'state': 'closed',
#     'ts_max_regions': 1,
#     'tc_max_regions': 1}},
#   {'timestamp': '2025-07-10T16:51:12.207254+0000',
#    'flow_id': 735835374577567,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': '172.24.0.6',
#    'src_port': 40018,
#    'dest_ip': '172.24.0.3',
#    'dest_port': 80,
#    'proto': 'TCP',
#    'app_proto': 'http',
#    'flow': {'pkts_toserver': 8,
#     'pkts_toclient': 6,
#     'bytes_toserver': 925,
#     'bytes_toclient': 2530,
#     'start': '2025-07-10T16:51:06.695613+0000',
#     'end': '2025-07-10T16:51:06.701778+0000',
#     'age': 0,
#     'state': 'closed',
#     'reason': 'shutdown',
#     'alerted': False},
#    'tcp': {'tcp_flags': '1b',
#     'tcp_flags_ts': '1b',
#     'tcp_flags_tc': '1b',
#     'syn': True,
#     'fin': True,
#     'psh': True,
#     'ack': True,
#     'state': 'closed',
#     'ts_max_regions': 1,
#     'tc_max_regions': 1}},
#   {'timestamp': '2025-07-10T16:51:12.207267+0000',
#    'flow_id': 1197371684992922,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': '172.24.0.6',
#    'src_port': 40820,
#    'dest_ip': '172.24.0.3',
#    'dest_port': 80,
#    'proto': 'TCP',
#    'app_proto': 'http',
#    'flow': {'pkts_toserver': 6,
#     'pkts_toclient': 4,
#     'bytes_toserver': 544,
#     'bytes_toclient': 553,
#     'start': '2025-07-10T16:50:20.278784+0000',
#     'end': '2025-07-10T16:50:20.282147+0000',
#     'age': 0,
#     'state': 'closed',
#     'reason': 'shutdown',
#     'alerted': False},
#    'tcp': {'tcp_flags': '1b',
#     'tcp_flags_ts': '1b',
#     'tcp_flags_tc': '1b',
#     'syn': True,
#     'fin': True,
#     'psh': True,
#     'ack': True,
#     'state': 'closed',
#     'ts_max_regions': 1,
#     'tc_max_regions': 1}},
#   {'timestamp': '2025-07-10T16:51:12.207369+0000',
#    'flow_id': 597384581337311,
#    'in_iface': 'eth0',
#    'event_type': 'flow',
#    'src_ip': '172.24.0.6',
#    'src_port': 33182,
#    'dest_ip': '172.24.0.3',
#    'dest_port': 80,
#    'proto': 'TCP',
#    'app_proto': 'http',
#    'flow': {'pkts_toserver': 6,
#     'pkts_toclient': 4,
#     'bytes_toserver': 544,
#     'bytes_toclient': 553,
#     'start': '2025-07-10T16:50:50.597841+0000',
#     'end': '2025-07-10T16:50:50.600109+0000',
#     'age': 0,
#     'state': 'closed',
#     'reason': 'shutdown',
#     'alerted': False},
#    'tcp': {'tcp_flags': '1b',
#     'tcp_flags_ts': '1b',
#     'tcp_flags_tc': '1b',
#     'syn': True,
#     'fin': True,
#     'psh': True,
#     'ack': True,
#     'state': 'closed',
#     'ts_max_regions': 1,
#     'tc_max_regions': 1}}]}

# %%
json_to_save = join_jsons(list(flow_jsons.values()))
save_json(json_to_save, 'eve_flow_data.json')

# %%
def flatten_entry(entry):
    flat = {}
    for k, v in entry.items():
        if isinstance(v, dict):
            for sub_k, sub_v in v.items():
                flat[f"{k}.{sub_k}"] = sub_v
        else:
            flat[k] = v
    return flat

flow_jsons = json.dumps(flow_jsons)
flattened_records = [flatten_entry(e) for e in flow_jsons]
df = pd.DataFrame(flattened_records)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 12
#       9     return flat
#      11 flow_jsons = json.dumps(flow_jsons)
# ---> 12 flattened_records = [flatten_entry(e) for e in flow_jsons]
#      13 df = pd.DataFrame(flattened_records)
#
# Cell In[35], line 3, in flatten_entry(entry)
#       1 def flatten_entry(entry):
#       2     flat = {}
# ----> 3     for k, v in entry.items():
#       4         if isinstance(v, dict):
#       5             for sub_k, sub_v in v.items():
#
# AttributeError: 'str' object has no attribute 'items'
